# %%
import pandas as pd

# %%
df = pd.read_csv('../data/yellow_tripdata_2019-01.csv')

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5           1                  N           151           239
# 1            2.6           1                  N           239           246
# 2            0.0           1                  N           236           236
# 3            0.0           1                  N           193           193
# 4            0.0           2                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.shape
# Out:
# (7667792, 18)

# %%
# this seems to indicate that every single record has a null value in the row??
# nope, actually this just returns True or False
df.isna()
# Out:
#          VendorID  tpep_pickup_datetime  tpep_dropoff_datetime  \
# 0           False                 False                  False
# 1           False                 False                  False
# 2           False                 False                  False
# 3           False                 False                  False
# 4           False                 False                  False
# ...           ...                   ...                    ...
# 7667787     False                 False                  False
# 7667788     False                 False                  False
# 7667789     False                 False                  False
# 7667790     False                 False                  False
# 7667791     False                 False                  False
#
#          passenger_count  trip_distance  RatecodeID  store_and_fwd_flag  \
# 0                  False          False       False               False
# ...

# %%
df.isna().values.any()
# Out:
# True

# %%
# *This* is how to determine the number of missing values
df.isnull().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count                0
# trip_distance                  0
# RatecodeID                     0
# store_and_fwd_flag             0
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge     4855978
# dtype: int64
